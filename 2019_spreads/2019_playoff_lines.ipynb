# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Set URL and headers
url = "https://www.sportsbookreviewsonline.com/scoresoddsarchives/nba-odds-2018-19/"
headers = {
    "User-Agent": "Mozilla/5.0"
}

# %%
# Get and parse the page
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Find the table by class name
table = soup.find("table", class_="table bg-white table-hover table-bordered table-sm")

# %%
# Read the HTML table into a DataFrame
df = pd.read_html(str(table))[0]
df.columns = df.iloc[0]
df = df.drop(index=0).reset_index(drop=True)
# Out:
# /var/folders/_n/bpjqqp157hv5dsr_3glytm1h0000gp/T/ipykernel_80670/1464038203.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]

# %%
# Preview and clean (optional)
df.columns = df.columns.droplevel(0) if isinstance(df.columns, pd.MultiIndex) else df.columns
df = df.dropna(how='all')  # Drop rows that are completely empty

# %%
# Display
df.head()
# Out:
# 0  Date  Rot VH          Team 1st 2nd 3rd 4th Final   Open  Close     ML  \
# 0  1016  501  V  Philadelphia  21  21  24  21    87  208.5  211.5    170
# 1  1016  502  H        Boston  21  26  30  28   105      5    4.5   -200
# 2  1016  503  V  OklahomaCity  23  24  32  21   100  223.5  220.5    711
# 3  1016  504  H   GoldenState  31  26  26  25   108   11.5     12  -1100
# 4  1017  701  V       Memphis  16  23  19  25    83    209  204.5    263
#
# 0     2H
# 0    106
# 1      1
# 2  108.5
# 3    4.5
# 4      1

# %%
# First, make sure the Date column is treated as an integer
df["Date"] = df["Date"].astype(int)

# Filter for playoff dates
df = df[(df["Date"] >= 413) & (df["Date"] <= 613)]

# Preview filtered DataFrame
df.head()
# Out:
# 0     Date  Rot VH          Team 1st 2nd 3rd 4th Final   Open  Close    ML  \
# 2460   413  501  V      Brooklyn  31  31  31  18   111    232  228.5   280
# 2461   413  502  H  Philadelphia  22  32  28  20   102      7      8  -360
# 2462   413  503  V       Orlando  25  32  18  29   104    216  212.5   375
# 2463   413  504  H       Toronto  30  19  27  25   101    7.5    9.5  -500
# 2464   413  505  V    LAClippers  27  29  23  25   104  230.5    234   900
#
# 0        2H
# 2460    118
# 2461    8.5
# 2462  105.5
# 2463   10.5
# 2464  114.5

# %%
df.to_csv("2019_playoffs_spreads.csv", index=False)
