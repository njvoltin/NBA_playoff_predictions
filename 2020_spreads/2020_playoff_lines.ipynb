# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Set URL and headers
url = "https://www.sportsbookreviewsonline.com/scoresoddsarchives/nba-odds-2019-20/"
headers = {
    "User-Agent": "Mozilla/5.0"
}

# %%
# Get and parse the page
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Find the table by class name
table = soup.find("table", class_="table bg-white table-hover table-bordered table-sm")

# %%
# Read the HTML table into a DataFrame
df = pd.read_html(str(table))[0]
df.columns = df.iloc[0]
df = df.drop(index=0).reset_index(drop=True)
# Out:
# /var/folders/_n/bpjqqp157hv5dsr_3glytm1h0000gp/T/ipykernel_77835/1464038203.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]

# %%
# Preview and clean (optional)
df.columns = df.columns.droplevel(0) if isinstance(df.columns, pd.MultiIndex) else df.columns
df = df.dropna(how='all')  # Drop rows that are completely empty

# %%
# Display
df.head()
# Out:
# 0  Date  Rot VH        Team 1st 2nd 3rd 4th Final   Open  Close    ML     2H
# 0  1022  501  V  NewOrleans  30  31  25  31   122  231.5  229.5   230    113
# 1  1022  502  H     Toronto  27  29  32  29   130    6.5    6.5  -280      6
# 2  1022  503  V    LALakers  25  29  31  17   102    227    3.5  -180      5
# 3  1022  504  H  LAClippers  22  40  23  27   112    1.5    224   150  110.5
# 4  1023  505  V     Detroit  27  27  29  36   119    210    211   240    104

# %%
# First, make sure the Date column is treated as an integer
df["Date"] = df["Date"].astype(int)

# Filter for playoff dates
df = df[(df["Date"] >= 817) & (df["Date"] <= 1011)]

# Preview filtered DataFrame
df.head()
# Out:
# 0     Date  Rot VH          Team 1st 2nd 3rd 4th Final   Open  Close    ML  \
# 2120   817  751  N          Utah  25  27  31  32   125  220.5    214   160
# 2121   817  752  N        Denver  31  28  19  37   135      2      4  -180
# 2122   817  753  N      Brooklyn  20  31  35  24   110    224  222.5   450
# 2123   817  754  N       Toronto  37  36  22  39   134     10     10  -600
# 2124   817  755  N  Philadelphia  26  23  30  22   101    220    217   230
#
# 0        2H
# 2120  109.5
# 2121    0.5
# 2122    0.5
# 2123    109
# 2124    110

# %%
df.to_csv("2020_playoffs_spreads.csv", index=False)
