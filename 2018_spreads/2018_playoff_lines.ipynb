# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Set URL and headers
url = "https://www.sportsbookreviewsonline.com/scoresoddsarchives/nba-odds-2017-18/"
headers = {
    "User-Agent": "Mozilla/5.0"
}

# %%
# Get and parse the page
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Find the table by class name
table = soup.find("table", class_="table bg-white table-hover table-bordered table-sm")

# %%
# Read the HTML table into a DataFrame
df = pd.read_html(str(table))[0]
df.columns = df.iloc[0]
df = df.drop(index=0).reset_index(drop=True)
# Out:
# /var/folders/_n/bpjqqp157hv5dsr_3glytm1h0000gp/T/ipykernel_82500/1464038203.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]

# %%
# Preview and clean (optional)
df.columns = df.columns.droplevel(0) if isinstance(df.columns, pd.MultiIndex) else df.columns
df = df.dropna(how='all')  # Drop rows that are completely empty

# %%
# Display
df.head()
# Out:
# 0  Date  Rot VH         Team 1st 2nd 3rd 4th Final   Open  Close    ML     2H
# 0  1017  501  V       Boston  19  19  33  28    99  214.5    216   166    1.5
# 1  1017  502  H    Cleveland  29  25  18  30   102      4    4.5  -195    110
# 2  1017  503  V      Houston  34  28  26  34   122    232  231.5   364  115.5
# 3  1017  504  H  GoldenState  35  36  30  20   121      9      9  -470    2.5
# 4  1018  701  V     Brooklyn  30  33  35  33   131    212  216.5   135  112.5

# %%
# First, make sure the Date column is treated as an integer
df["Date"] = df["Date"].astype(int)

# Filter for playoff dates
df = df[(df["Date"] >= 414) & (df["Date"] <= 608)]

# Preview filtered DataFrame
df.head()
# Out:
# 0     Date  Rot VH         Team 1st 2nd 3rd 4th Final Open  Close    ML     2H
# 2460   414  501  V   SanAntonio  17  24  22  29    92  210  205.5   300    105
# 2461   414  502  H  GoldenState  28  29  29  27   113    8      8  -400    0.5
# 2462   414  503  V   Washington  23  36  26  21   106  211    214   275    106
# 2463   414  504  H      Toronto  28  27  31  28   114  7.5    7.5  -350      7
# 2464   414  505  V        Miami  35  25  18  25   103  210    214   200  105.5

# %%
df.to_csv("2018_playoffs_spreads.csv", index=False)
